# %% [markdown]
# # Computing material intensity coefficients

# %% [markdown]
# This notebook deals with how to convert results from the model into material intensity coefficients for comparison with other studies.

# %% [markdown]
# ## Setup

# %%
import psycopg as pg
import pandas as pd

# %%
params='dbname=macrocomponents3 user=postgres password=19Ni93co44PG!'

# %%
material_types=['Metal','Concrete','Aggregates','Wood','Wool','Other','Glass','Cement_mortar','Gypsum_plaster','Clay']
elements=['ext_wall','int_wall','floor','foundation','roof_cover','roof_structure','window','ridge_board', 'top_floor_ceiling', 'ground_slab']

# %%
def run_sql (DBparameters,SQLcode):
    try:
        # connect to the PostgreSQL database
        connector = pg.connect(DBparameters)

        # create a new cursor
        cur = connector.cursor()

        # execute the SQL statement
        cur.execute(SQLcode)

        # commit the changes to the database
        connector.commit()

        # close communication with the database
        cur.close()

    except (Exception, pg.DatabaseError) as error:
        print(error)

    finally:
        if connector is not None:
            connector.close()

# %% [markdown]
# ## Block-wise Material intensity coefficients

# %% [markdown]
# This section computes block-wise material intensity coefficients in the same format as Lanau & Liu (2020) "Developing an Urban Resource Cadaster for Circular Economy: A Case of Odense, Denmark". Material intensity coefficients are calculated for the "under-block", corresponding to all underground elements, the "vertical block" corresponding to walls, the "horizontal block" corresponding to intermediate floors, and the "over-block" corresponding to the roof, attic, etc. The OB and UB MICs are calculated per m2 footprint, whereas the VB MIC is per m2 footprint and per floor, and the HB MIC per m2 of intermediate floors.

# %%
def materials_per_element(material_types, elements):
    SQL="""CREATE TABLE IF NOT EXISTS materials_per_element (bbr_id varchar(50) PRIMARY KEY, """
    
    for m in material_types:
        for e in elements:
            SQL+=m+'_'+e+' real, '
    SQL=SQL[0:len(SQL)-2]+'); '
    
    SQL+="""WITH t AS(
    SELECT
    rma.bbr_id,
    rma.element,
    rma.product,
    weight,
    material_type
    FROM results_material_amounts rma
    INNER JOIN products pr ON rma.product=pr.name,
    LATERAL (SELECT (CASE WHEN unit='KG' THEN amount WHEN unit='M3' THEN amount*pr.density ELSE NULL END) AS weight) lt
    )

    SELECT
    bbr_id,
    SUM(weight) weightsum,
    material_type,
    element
    INTO TEMP TABLE t2
    FROM t
    GROUP BY material_type, bbr_id, element
    ORDER BY bbr_id;
    
    DELETE FROM materials_per_element;

    """
    for m in material_types:
        for e in elements:
            SQL+="INSERT INTO materials_per_element(bbr_id, "+m+'_'+e+") SELECT bbr_id, weightsum FROM t2 WHERE material_type = '"+m+"' AND element = '"+e+"' ON CONFLICT ON CONSTRAINT materials_per_element_pkey DO UPDATE SET (bbr_id, "+m+'_'+e+") = (EXCLUDED.bbr_id, EXCLUDED."+m+'_'+e+"); "

    try:
        conn = pg.connect(params)
        cur=conn.cursor()
        
        cur.execute(SQL)

        conn.commit()
        cur.close()
        
    except (Exception, pg.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()

# %%
materials_per_element(material_types, elements)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [141], line 1
# ----> 1 materials_per_element(material_types, elements)
#
# Cell In [140], line 42, in materials_per_element(material_types, elements)
#      39 conn = pg.connect(params)
#      40 cur=conn.cursor()
# ---> 42 cur.execute(SQL)
#      44 conn.commit()
#      45 cur.close()
#
# File ~\Anaconda3\lib\site-packages\psycopg\cursor.py:721, in Cursor.execute(self, query, params, prepare, binary)
#     719 try:
#     720     with self._conn.lock:
# --> 721         self._conn.wait(
#     722             self._execute_gen(query, params, prepare=prepare, binary=binary)
#     723         )
#     724 except e.Error as ex:
#     725     raise ex.with_traceback(None)
#
# File ~\Anaconda3\lib\site-packages\psycopg\connection.py:954, in Connection.wait(self, gen, timeout)
#     947 """
#     948 Consume a generator operating on the connection.
#     949
#     950 The function must be used on generators that don't change connection
#     951 fd (i.e. not on connect and reset).
#     952 """
#     953 try:
# --> 954     return waiting.wait(gen, self.pgconn.socket, timeout=timeout)
#     955 except KeyboardInterrupt:
#     956     # On Ctrl-C, try to cancel the query in the server, otherwise
#     957     # the connection will remain stuck in ACTIVE state.
#     958     c = self.pgconn.get_cancel()
#
# File ~\Anaconda3\lib\site-packages\psycopg\waiting.py:57, in wait_selector(gen, fileno, timeout)
#      55 rlist = None
#      56 while not rlist:
# ---> 57     rlist = sel.select(timeout=timeout)
#      58 sel.unregister(fileno)
#      59 # note: this line should require a cast, but mypy doesn't complain
#
# File ~\Anaconda3\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File ~\Anaconda3\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:

# %%
def mics(material):
    dic={'ob':[],'hb':[],'ub':[],'vb':[]}
    index=[]
    
    SQL="""SELECT 
    b.id_lokalid,
    ob,
    hb,
    ub,
    vb
    FROM materials_per_element mpe
    INNER JOIN buildings b ON b.id_lokalid=mpe.bbr_id,
    LATERAL (SELECT (CASE WHEN (b.byg041BebyggetAreal>0 AND b.byg054AntalEtager>0) THEN (COALESCE(%s_ext_wall,0)+COALESCE(%s_int_wall,0)+COALESCE(%s_window,0))/(b.byg041BebyggetAreal*b.byg054AntalEtager) ELSE NULL END) AS vb) lvb,
    LATERAL (SELECT (CASE WHEN (b.byg041BebyggetAreal>0) THEN (COALESCE(%s_roof_structure,0)+COALESCE(%s_roof_cover,0)+COALESCE(%s_ridge_board,0)+COALESCE(%s_top_floor_ceiling,0)+COALESCE(%s_top_floor_ceiling,0))/b.byg041BebyggetAreal ELSE NULL END) AS ob) lob,
    LATERAL (SELECT (CASE WHEN (b.byg041BebyggetAreal>0) THEN (COALESCE(%s_foundation,0)+COALESCE(%s_ground_slab,0))/b.byg041BebyggetAreal ELSE NULL END) AS ub) lub,
    LATERAL (SELECT (CASE WHEN (b.byg041BebyggetAreal>0 AND b.byg054AntalEtager>1) THEN COALESCE(%s_floor,0)/(b.byg041BebyggetAreal*(b.byg054AntalEtager-1)) ELSE NULL END) AS hb) lhb
    ORDER BY id_lokalid ASC""" % (material,material,material,material,material,material,material,material,material,material,material)
    
   
    try:
        conn = pg.connect(params)
        cur=conn.cursor()
        
        cur.execute(SQL)
        
        row=cur.fetchone()     
              
        while row is not None:
            index.append(row[0])
            n=1
            for k in dic.keys():
                dic[k].append(row[n])
                n+=1

            row=cur.fetchone()
            
        results=pd.DataFrame(dic,index)

        conn.commit()
        cur.close()
        
        return(results)
        
    except (Exception, pg.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()

# %%
m=mics('clay')

# %%
m

# %%
def all_mics(materials):
    dic={}
    index=[]

    for m in materials:
        ob=m+'_ob'
        hb=m+'_hb'
        ub=m+'_ub'    
        vb=m+'_vb'
    
        dic[ob]=[]
        dic[hb]=[]
        dic[ub]=[]
        dic[vb]=[]
    
        SQL="""SELECT 
        b.id_lokalid,
        ob,
        hb,
        ub,
        vb
        FROM materials_per_element mpe
        INNER JOIN buildings b ON b.id_lokalid=mpe.bbr_id,
        LATERAL (SELECT (CASE WHEN (b.byg041BebyggetAreal>0 AND b.byg054AntalEtager>0) THEN (COALESCE(%s_ext_wall,0)+COALESCE(%s_int_wall,0)+COALESCE(%s_window,0))/(b.byg041BebyggetAreal*b.byg054AntalEtager) ELSE NULL END) AS vb) lvb,
        LATERAL (SELECT (CASE WHEN (b.byg041BebyggetAreal>0) THEN (COALESCE(%s_roof_structure,0)+COALESCE(%s_roof_cover,0)+COALESCE(%s_ridge_board,0)+COALESCE(%s_top_floor_ceiling,0)+COALESCE(%s_top_floor_ceiling,0))/b.byg041BebyggetAreal ELSE NULL END) AS ob) lob,
        LATERAL (SELECT (CASE WHEN (b.byg041BebyggetAreal>0) THEN (COALESCE(%s_foundation,0)+COALESCE(%s_ground_slab,0))/b.byg041BebyggetAreal ELSE NULL END) AS ub) lub,
        LATERAL (SELECT (CASE WHEN (b.byg041BebyggetAreal>0 AND b.byg054AntalEtager>1) THEN COALESCE(%s_floor,0)/(b.byg041BebyggetAreal*(b.byg054AntalEtager-1)) ELSE NULL END) AS hb) lhb
        ORDER BY id_lokalid ASC""" % (m,m,m,m,m,m,m,m,m,m,m)


        try:
            conn = pg.connect(params, row_factory=pg.rows.dict_row)
            cur=conn.cursor()

            cur.execute(SQL)

            row=cur.fetchone()     

            while row is not None:
                if m==materials[0]:
                    index.append(row['id_lokalid'])

                dic[ob].append(row['ob'])
                dic[hb].append(row['hb'])
                dic[ub].append(row['ub'])
                dic[vb].append(row['vb'])

                row=cur.fetchone()

            cur.close()

        except (Exception, pg.DatabaseError) as error:
            print(error)
        finally:
            if conn is not None:
                conn.close()           
            
    results=pd.DataFrame(dic,index)
    return(results)

# %%
All_MICs=all_mics(material_types)

# %% [markdown]
# #### Reading data from SDU model:

# %%
SDU=pd.read_csv('C:/Users/KJ35FA/Downloads/bhuvans data.csv', sep=';')

# %%
def lowercase(str):
    return str.lower()

# %%
SDU['bygning_id']=SDU['bygning_id'].transform(lowercase)

# %%
SDU.index=[x.lower() for x in SDU['bygning_id']]

# %% [markdown]
# #### Computing MICs per archetype

# %%
AMSDU=pd.merge(All_MICs, SDU, left_index=True, right_index=True, how='inner')

# %%
AMSDU.describe()
# Out:
#            Metal_ob    Metal_hb      Metal_ub      Metal_vb   Concrete_ob  \
# count  28914.000000  1047.00000  28914.000000  27953.000000  28914.000000
# mean       1.017647    11.14361     20.390413      4.206760      8.504102
# std        2.786577    10.06333      4.445969      4.029882     20.401182
# min        0.000000     0.10000      0.000000      0.032994      0.000000
# 25%        0.000000     4.45000     21.899999      0.780875      0.000000
# 50%        0.000000     9.24000     21.900000      2.471509      0.000000
# 75%        0.000000     9.24000     21.900000      7.479962      0.000000
# max       14.940001    33.50000     21.900001     91.978160     79.421598
#
#        Concrete_hb   Concrete_ub   Concrete_vb  Aggregates_ob  Aggregates_hb  \
# count  1047.000000  28914.000000  27953.000000        28914.0         1047.0
# mean     88.554609   1004.548663     64.427315            0.0            0.0
# std     112.506992    222.170859     83.967347            0.0            0.0
# min       0.000000      0.000000      0.000000            0.0            0.0
# 25%       0.000000   1080.000000      0.000000            0.0            0.0
# 50%      78.800002   1080.000000     35.516251            0.0            0.0
# 75%      95.999991   1080.000000    101.551037            0.0            0.0
# max     384.000000   1080.000000   1344.359863            0.0            0.0
#
#        ...     aggregates          clay      concrete     glasscera  \
# count  ...   28914.000000  2.891400e+04  2.891400e+04  28914.000000
# mean   ...   18732.001805  9.102313e+04  1.667727e+05    368.128414
# std    ...   22861.530954  2.557602e+05  3.835930e+05    610.069500
# min    ...       0.000000  1.020000e+02  1.412000e+03      0.000000
# 25%    ...       0.000000  1.697600e+04  6.484400e+04      0.000000
# 50%    ...   13710.000610  3.584000e+04  9.018640e+04    224.000000
# 75%    ...   32678.400450  1.041760e+05  1.375060e+05    552.000000
# max    ...  724681.968400  1.161063e+07  1.907939e+07  17093.999750
#
#              metals     mortargyp      plastics        timber  othermaterials  \
# count  2.891400e+04  2.891400e+04  28914.000000  2.891400e+04    2.891400e+04
# mean   1.835698e+04  4.392095e+04    119.525191  1.590817e+04    5.417471e+04
# std    8.630917e+04  1.657184e+05    270.643176  3.244685e+04    2.164534e+05
# min    7.040000e+01  0.000000e+00      0.000000  7.080000e+01    7.500000e+01
# 25%    1.269000e+03  8.791200e+03      0.000000  5.953500e+03    1.720000e+03
# 50%    2.150400e+03  2.023700e+04     20.000000  9.369600e+03    3.360500e+03
# 75%    1.061250e+04  3.469200e+04    153.600002  1.677000e+04    4.132800e+04
# max    4.885160e+06  7.867610e+06  13753.500490  1.544450e+06    9.134580e+06
#
#        totalmaterial
# count   2.891400e+04
# mean    4.093747e+05
# std     1.067387e+06
# min     3.193800e+03
# 25%     1.586376e+05
# 50%     2.235660e+05
# 75%     3.421638e+05
# max     4.468548e+07
#
# [8 rows x 70 columns]

# %%
nogs=pd.merge(allresults,AMSDU.query('(archetype == "SFH") & opfoerelse_aar < 1850').sort_values(by='Concrete_ub')

# %%
archetypes=list(dict.fromkeys(AMSDU['archetype']))
archetypes
# Out:
# ['SFH', 'TH', 'NRO', 'NRT', 'NRF', 'AB', 'NRA']

# %%
years=[0, 1850, 1930, 1950, 1960, 1972, 1978, 1998, 2006, 2010, 2100]

# %%
AMSDU.columns
# Out:
# Index(['Metal_ob', 'Metal_hb', 'Metal_ub', 'Metal_vb', 'Concrete_ob',
#        'Concrete_hb', 'Concrete_ub', 'Concrete_vb', 'Aggregates_ob',
#        'Aggregates_hb', 'Aggregates_ub', 'Aggregates_vb', 'Wood_ob', 'Wood_hb',
#        'Wood_ub', 'Wood_vb', 'Wool_ob', 'Wool_hb', 'Wool_ub', 'Wool_vb',
#        'Other_ob', 'Other_hb', 'Other_ub', 'Other_vb', 'Glass_ob', 'Glass_hb',
#        'Glass_ub', 'Glass_vb', 'Cement_mortar_ob', 'Cement_mortar_hb',
#        'Cement_mortar_ub', 'Cement_mortar_vb', 'Gypsum_plaster_ob',
#        'Gypsum_plaster_hb', 'Gypsum_plaster_ub', 'Gypsum_plaster_vb',
#        'Clay_ob', 'Clay_hb', 'Clay_ub', 'Clay_vb', 'id', 'geom', 'bygning_id',
#        'ydervaeg_kode', 'suppydervaegmat', 'tag_kode', 'supptagdaekmat',
#        'opfoerelse_aar', 'ombyg_aar', 'byg_anvend_kode', 'byg_arl_saml',
#        'erhv_arl_saml', 'udhus_indb_arl', 'carport_indb_arl',
#        'garage_indb_arl', 'udhus_indb_arl(2)', 'andet_arl', 'overdaekareal',
#        'etager_ant', 'komkode', 'grund_id', 'koornord', 'kooroest',
#        'archetype', 'aggregates', 'clay', 'concrete', 'glasscera', 'metals',
#        'mortargyp', 'plastics', 'timber', 'othermaterials', 'totalmaterial'],
#       dtype='object')

# %%
mic_dic={}

for a in archetypes:
    for n in range(1,len(years)):
        ymax=str(years[n])
        ymin=str(years[n-1])
        name=a+ymax
        q='(archetype == "'+a+'") & (opfoerelse_aar <= '+ymax+') & (opfoerelse_aar > '+ymin+')'
        mic_dic[name]=AMSDU.query(q)

# %%
mic_dic['SFH1850']
# Out:
#                                       Metal_ob  Metal_hb  Metal_ub  Metal_vb  \
# 00766d80-9540-49ec-8629-5f4d38e7e0b4       0.0       NaN       0.0  0.790575
# 032bb210-9b37-49aa-8984-9b535f7980f1       0.0       NaN       7.5  7.580735
# 043a4700-59ae-4416-8f22-7c17fd0b0303       0.0       NaN       7.5  7.685243
# 0479ddf8-c994-426a-80b4-e0adecb7c95e       0.1       NaN       0.0  7.852956
# 047c409e-0d69-42e1-9b44-92ff994e746b       0.0       NaN       7.5  1.054100
# ...                                        ...       ...       ...       ...
# f9289914-a491-488e-b9a8-b1a6284a4164       0.1       NaN       7.5  7.870970
# f955734d-8216-402d-a7eb-9fc214d9d75c       0.0       NaN       7.5  1.263869
# fce9ed5c-107f-4751-9d9c-ba0048ac933a       0.0       NaN       7.5  2.648670
# fe6e35e9-8ad6-4bbe-b8b6-c2f51ade9e0f       0.1       NaN       7.5  7.744189
# aabae4db-67b7-46b7-b9b1-8b0c067d5137       0.1       NaN       0.0  5.809299
#
#                                       Concrete_ob  Concrete_hb  Concrete_ub  \
# fce9ed5c-107f-4751-9d9c-ba0048ac933a    114951.6018
# fe6e35e9-8ad6-4bbe-b8b6-c2f51ade9e0f    189514.8030
# aabae4db-67b7-46b7-b9b1-8b0c067d5137    394563.6062
#
# [269 rows x 74 columns]

# %%
mic_means={}
for k in mic_dic.keys():
    means=mic_dic[k].mean(numeric_only=True)
    mic_means[k]=means

# %%
mic_meds={}
for k in mic_dic.keys():
    meds=mic_dic[k].median(numeric_only=True)
    mic_meds[k]=meds

# %%
mic_10={}
for k in mic_dic.keys():
    q=mic_dic[k].quantile(0.1)
    mic_10[k]=q

# %%
mic_90={}
for k in mic_dic.keys():
    q=mic_dic[k].quantile(0.9)
    mic_90[k]=q

# %%
mic_std={}
for k in mic_dic.keys():
    std=mic_dic[k].std(numeric_only=True)
    mic_std[k]=std

# %%
MICS={}
for k in mic_dic.keys():
    d={}
    d['mean']=mic_means[k]
    d['median']=mic_meds[k]
    d['10q']=mic_10[k]
    d['90q']=mic_90[k]
    d['std']=mic_std[k]
    MICS[k]=d

# %%
MICS['SFH1850']['mean']
# Out:
# Metal_ob               0.540818
# Metal_hb               3.146666
# Metal_ub               6.412639
# Metal_vb               3.222186
# Concrete_ob            3.806510
#                       ...
# mortargyp          24358.689283
# plastics             317.549455
# timber             19370.515178
# othermaterials      2474.239506
# totalmaterial     205533.879810
# Length: 70, dtype: float64

# %%
mics_list=[]
for k in MICS.keys():
    df=pd.DataFrame({k:MICS[k]['mean']})
    mics_list.append(df)
mics_table=pd.concat(mics_list, axis=1)

# %%
mics_table.to_csv('C:/Users/KJ35FA/Documents/Python/MICS.csv', sep=';')

# %% [markdown]
# # Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
boxplot=AMSDU.boxplot(column=['Clay_vb','Concrete_vb','Wood_vb'])

# %%
boxplot.figure

# %%
import seaborn as sns

# %%
kde=sns.displot(AMSDU,x='Concrete_vb')

# %%
kde.set(ylim=(0,350))

# %%
kde.figure

# %% [markdown]
# ## Material intensity coefficients per m2

# %% [markdown]
# This section computes MICs at the building level in kg material per m2 of floor area. This is a common indicator, useful for comparison with previous studies.

# %%
def all_mics2(materials):
    dic={}
    for m in materials:
        dic[m]=[]
    index=[]
    SQL="SELECT mpe.*, b.byg038SamletBygningsareal FROM materials_per_element mpe INNER JOIN buildings b ON b.id_lokalid=mpe.bbr_id ORDER BY id_lokalid ASC"
    conn=None 
    
    try:
        conn = pg.connect(params, row_factory=pg.rows.dict_row)
        cur=conn.cursor()

        cur.execute(SQL)

        row=cur.fetchone()
        
        while row is not None:

            for m in materials:
                material_amount=0    
                if m==materials[0]:
                    index.append(row['bbr_id'])
                    
                for k in row.keys():
                    if m in k:
                    material_amount+=row[k]    

                dic[m].append(material_amount/row['byg038SamletBygningsareal'])

            row=cur.fetchone()

            cur.close()

        except (Exception, pg.DatabaseError) as error:
            print(error)
        finally:
            if conn is not None:
                conn.close()           
            
    results=pd.DataFrame(dic,index)
    return(results)
